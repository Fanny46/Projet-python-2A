# %%
"""Librairies nécessaires"""
import pandas as pd
import geopandas as gpd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import statsmodels.api as sm
from matplotlib.backends.backend_agg import FigureCanvasAgg
import os

# %%
"""Changement de directory pour lire les fichiers"""
import os
os.getcwd() #trouver le directory actuel 
os.chdir('/home/onyxia/work/Projet-Stat-App-2A')

# %%
"""Chargement fichier dvf"""

path_folder = '3.2) Données finales/'
name_file = 'dvf_final_2021_to_2023.geojson'
path_file = path_folder + name_file

dvf = gpd.read_file(path_file)
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/mamba/share/proj failed

# %%
dvf_reg = dvf.copy()

# %%
dvf_reg.columns
# Out:
# Index(['id_mutation', 'date_mutation', 'prix', 'log_prix',
#        'nombre_pieces_principales', 'surface_reelle_bati', 'surface_carrez',
#        'nombre_dependances', 'prix_au_m2_carrez', 'prix_au_m2_reel_bati',
#        'adresse_numero', 'adresse_nom_voie', 'code_postal', 'code_commune',
#        'nom_arrondissement', 'num_arrondissement', 'nom_quartier',
#        'dist_min_lycee', 'nom_lycee', 'dist_min_grand_parc', 'dist_min_square',
#        'nom_grand_parc', 'nom_square', 'dist_min_site_tour', 'nom_site_tour',
#        'dist_min_stat', 'nom_stat', 'num_ligne', 'dist_min_log_social',
#        'dist_min_voie_eau', 'longitude', 'latitude',
#        'dist_min_grand_parc_ind_1', 'dist_min_grand_parc_ind_2',
#        'dist_min_grand_parc_ind_3', 'dist_min_square_ind_1',
#        'dist_min_square_ind_2', 'dist_min_square_ind_3',
#        'dist_min_site_tour_ind_1', 'dist_min_site_tour_ind_2',
#        'dist_min_site_tour_ind_3', 'dist_min_lycee_ind_1',
#        'dist_min_lycee_ind_2', 'dist_min_lycee_ind_3', 'dist_min_stat_ind_1',
#        'dist_min_stat_ind_2', 'dist_min_stat_ind_3',
#        'dist_min_log_social_ind_1', 'dist_min_log_social_ind_2',
#        'dist_min_log_social_ind_3', 'dist_min_voie_eau_ind_1',
#        'dist_min_voie_eau_ind_2', 'dist_min_voie_eau_ind_3', 'geometry'],
#       dtype='object')

# %%
"""Choix des variables à mettre dans la régression"""

var_a_expliquer = 'log_prix'

var_explicatives_base = ['nombre_pieces_principales', 'surface_reelle_bati', 'nombre_dependances']

var_explicatives_avec_dist = ['nombre_pieces_principales', 'surface_reelle_bati', 'nombre_dependances',
                              'dist_min_grand_parc', 'dist_min_square', 'dist_min_site_tour', 'dist_min_stat', 'dist_min_lycee', 
                              'dist_min_log_social', 'dist_min_voie_eau']

var_explicatives_avec_dist_ind = ['nombre_pieces_principales', 'surface_reelle_bati', 'nombre_dependances',
                               'dist_min_grand_parc_ind_1', 'dist_min_grand_parc_ind_2',
                               'dist_min_grand_parc_ind_3', 'dist_min_square_ind_1',
                               'dist_min_square_ind_2', 'dist_min_square_ind_3',
                               'dist_min_site_tour_ind_1', 'dist_min_site_tour_ind_2',
                               'dist_min_site_tour_ind_3', 'dist_min_lycee_ind_1',
                               'dist_min_lycee_ind_2', 'dist_min_lycee_ind_3', 'dist_min_stat_ind_1',
                               'dist_min_stat_ind_2', 'dist_min_stat_ind_3',
                               'dist_min_log_social_ind_1', 'dist_min_log_social_ind_2',
                               'dist_min_log_social_ind_3', 'dist_min_voie_eau_ind_1',
                               'dist_min_voie_eau_ind_2', 'dist_min_voie_eau_ind_3']

# %%
"""Fonction qui réalise une régression linéaire simple multivariée"""

def regression_lineaire_multivariable(dvf, variable_a_expliquer, variables_explicatives, output_folder, dist='avec_dist', ind='ind'):
    
    # Séparer la variable dépendante et les variables indépendantes
    y = dvf[variable_a_expliquer]
    X = dvf[variables_explicatives]

    # Ajouter une colonne de constante pour l'intercept
    X = sm.add_constant(X)

    # Initialiser le modèle de régression linéaire avec des estimateurs de variance robustes
    model = sm.OLS(y, X).fit()
    #cov_type='HC3'
    
    # Créer une figure textuelle avec le résumé de la régression
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.axis('off')  # Masquer les axes
    ax.text(0, 0.95, str(model.summary()), va='top', ha='left', fontsize=10, family='monospace')

    # Sauvegarder la figure de résumé en format JPEG avec spécification de la résolution (dpi)
    summary_image_path = os.path.join(output_folder, f'regression_summary_{dist}_{ind}.jpg')
    fig.savefig(summary_image_path, format='jpeg', dpi=300)
    print(f"Résumé de régression exporté avec succès dans : {summary_image_path}")

    # Prédire les valeurs de y en fonction de X
    y_pred = model.predict(X)

    # Tracer la régression linéaire
    plt.figure(figsize=(10, 6))
    plt.scatter(y, y_pred, color='black')
    plt.plot([y.min(), y.max()], [y.min(), y.max()], linestyle='--', color='blue', linewidth=3, label='Régression linéaire')
    plt.xlabel('Valeurs réelles')
    plt.ylabel('Valeurs prédites')
    plt.legend()

    # Sauvegarder le graphique en format JPEG avec spécification de la résolution (dpi)
    regression_plot_path = os.path.join(output_folder, f'regression_plot_{dist}_{ind}.jpg')
    plt.savefig(regression_plot_path, format='jpeg', dpi=30)
    print(f"Graphique de régression exporté avec succès dans : {regression_plot_path}")

    # Afficher le graphique
    plt.show()

# %%
def regression_lineaire_multivariable(dvf, variable_a_expliquer, variables_explicatives, output_folder, dist='avec_dist', ind='ind'):
    
    # Séparer la variable dépendante et les variables indépendantes
    y = dvf[variable_a_expliquer]
    X = dvf[variables_explicatives]

    # Ajouter une colonne de constante pour l'intercept
    X = sm.add_constant(X)

    # Initialiser le modèle de régression linéaire avec des estimateurs de variance robustes
    model = sm.OLS(y, X).fit()
    
    # Créer une figure textuelle avec le résumé de la régression
    fig, ax = plt.subplots(figsize=(15, 10))  # Ajustez la taille de la figure selon vos besoins
    ax.axis('off')  # Masquer les axes
    ax.text(0, 0.95, str(model.summary()), va='top', ha='left', fontsize=10, family='monospace')

    # Sauvegarder la figure de résumé en format JPEG avec spécification de la résolution (dpi)
    summary_image_path = os.path.join(output_folder, f'regression_summary_{dist}_{ind}.jpg')
    fig.savefig(summary_image_path, format='jpeg', dpi=300)
    print(f"Résumé de régression exporté avec succès dans : {summary_image_path}")

    # Prédire les valeurs de y en fonction de X
    y_pred = model.predict(X)

    # Tracer la régression linéaire
    plt.figure(figsize=(10, 6))
    plt.scatter(y, y_pred, color='black')
    plt.plot([y.min(), y.max()], [y.min(), y.max()], linestyle='--', color='blue', linewidth=3, label='Régression linéaire')
    plt.xlabel('Valeurs réelles')
    plt.ylabel('Valeurs prédites')
    plt.legend()

    # Sauvegarder le graphique en format JPEG avec spécification de la résolution (dpi)
    regression_plot_path = os.path.join(output_folder, f'regression_plot_{dist}_{ind}.jpg')
    plt.savefig(regression_plot_path, format='jpeg', dpi=300)
    print(f"Graphique de régression exporté avec succès dans : {regression_plot_path}")

    # Afficher le graphique
    plt.show()

# %%
"""Appliquer la fonction"""

output_folder = '4) Modélisation/1) Regression_lineaire_simple/Sorties/'
var_a_expliquer = 'log_prix'

# Jeu de variables explicatives contenant les distances
regression_lineaire_multivariable(dvf_reg, var_a_expliquer, var_explicatives_avec_dist, output_folder, ind='')

# Jeu de variables explicatives avec les distances en indicatrices
regression_lineaire_multivariable(dvf_reg, var_a_expliquer, var_explicatives_avec_dist_ind, output_folder)
# Out:
# Résumé de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/Sorties/regression_summary_avec_dist_.jpg
# Graphique de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/Sorties/regression_plot_avec_dist_.jpg
# Résumé de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/Sorties/regression_summary_avec_dist_ind.jpg
# Graphique de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/Sorties/regression_plot_avec_dist_ind.jpg

# %%
"""Fonction qui réalise une régression linéaire simple multivariée dans un arrondissement"""

def regression_lineaire_multivariable_arr(dvf, arrondissement, variables_explicatives, variable_a_expliquer, output_folder):

    #sélection de l'arrondissement
    dvf = dvf.loc[dvf['code_postal']==arrondissement]
    
    # Sélectionner les colonnes spécifiées
    colonnes = variables_explicatives + [variable_a_expliquer]
    df_selected = dvf[colonnes].dropna()

    # Extraire les valeurs de X et y
    X = df_selected[variables_explicatives]
    y = df_selected[variable_a_expliquer]

    # Ajouter une colonne de constante pour l'intercept
    X = sm.add_constant(X)

    # Initialiser le modèle de régression linéaire
    model = sm.OLS(y, X).fit(cov_type='HC3')

    # Créer une figure textuelle avec le résumé de la régression
    fig, ax = plt.subplots(figsize=(10, 6))
    ax.axis('off')  # Masquer les axes
    ax.text(0, 0.95, str(model.summary()), va='top', ha='left', fontsize=10, family='monospace')

    # Sauvegarder la figure de résumé en format JPEG avec spécification de la résolution (dpi)
    summary_image_path = os.path.join(output_folder, f'regression_{arrondissement}_summary.jpg')
    fig.savefig(summary_image_path, format='jpeg', dpi=300)
    print(f"Résumé de régression exporté avec succès dans : {summary_image_path}")

    # Prédire les valeurs de y en fonction de X
    y_pred = model.predict(X)

    # Tracer la régression linéaire
    plt.figure(figsize=(10, 6))
    plt.scatter(y, y_pred, color='black')
    plt.plot([y.min(), y.max()], [y.min(), y.max()], linestyle='--', color='blue', linewidth=3, label='Régression linéaire')
    plt.xlabel('Valeurs réelles')
    plt.ylabel('Valeurs prédites')
    plt.legend()

    # Sauvegarder le graphique en format JPEG avec spécification de la résolution (dpi)
    regression_plot_path = os.path.join(output_folder, f'regression_{arrondissement}_plot.jpg')
    plt.savefig(regression_plot_path, format='jpeg', dpi=150)
    print(f"Graphique de régression exporté avec succès dans : {regression_plot_path}")

    # Afficher le graphique
    plt.show()

# %%
"""Régression dans plusieurs arrondissements"""

output_folder = '4) Modélisation/1) Regression_lineaire_simple/'

arrondissements_list = ['75005', '75013', '75019', '75007']

for arrondissement in arrondissements_list:
    regression_lineaire_multivariable_arr(dvf, arrondissement, var_explicatives_avec_ind_dist, var_a_expliquer, output_folder)
    print("\n" + "=" * 50 + "\n")  # Séparateur visuel entre les régressions
# Out:
# /opt/mamba/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1965: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /opt/mamba/lib/python3.10/site-packages/statsmodels/base/model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 8, but rank is 7
#   warnings.warn('covariance of constraints does not have full '
# Résumé de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75005_summary.jpg
# Graphique de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75005_plot.jpg
# ==================================================
#
# Résumé de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75013_summary.jpg
# Graphique de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75013_plot.jpg
# ==================================================
#
# Résumé de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75019_summary.jpg
# Graphique de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75019_plot.jpg
# ==================================================
# /opt/mamba/lib/python3.10/site-packages/statsmodels/regression/linear_model.py:1965: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.sqrt(eigvals[0]/eigvals[-1])
# /opt/mamba/lib/python3.10/site-packages/statsmodels/base/model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 8, but rank is 7
#   warnings.warn('covariance of constraints does not have full '
# Résumé de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75007_summary.jpg
# Graphique de régression exporté avec succès dans : 4) Modélisation/1) Regression_lineaire_simple/regression_75007_plot.jpg
# ==================================================
