# %%
"""Installations pour faire des cartes"""
# !pip install pandas fiona shapely pyproj rtree
# !pip install contextily
# !pip install geopandas
# !pip install topojson
# Out:
# Requirement already satisfied: pandas in /opt/mamba/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: fiona in /opt/mamba/lib/python3.10/site-packages (1.9.3)
# Requirement already satisfied: shapely in /opt/mamba/lib/python3.10/site-packages (2.0.2)
# Requirement already satisfied: pyproj in /opt/mamba/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: rtree in /opt/mamba/lib/python3.10/site-packages (1.1.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/mamba/lib/python3.10/site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/mamba/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/mamba/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: attrs>=19.2.0 in /opt/mamba/lib/python3.10/site-packages (from fiona) (23.1.0)
# Requirement already satisfied: certifi in /opt/mamba/lib/python3.10/site-packages (from fiona) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /opt/mamba/lib/python3.10/site-packages (from fiona) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.10/site-packages (from fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.10/site-packages (from fiona) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in /opt/mamba/lib/python3.10/site-packages (from fiona) (4.0.0)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: contextily in /opt/mamba/lib/python3.10/site-packages (1.4.0)
# Requirement already satisfied: geopy in /opt/mamba/lib/python3.10/site-packages (from contextily) (2.4.0)
# Requirement already satisfied: matplotlib in /opt/mamba/lib/python3.10/site-packages (from contextily) (3.8.1)
# Requirement already satisfied: mercantile in /opt/mamba/lib/python3.10/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /opt/mamba/lib/python3.10/site-packages (from contextily) (10.0.1)
# Requirement already satisfied: rasterio in /opt/mamba/lib/python3.10/site-packages (from contextily) (1.3.9)
# Requirement already satisfied: requests in /opt/mamba/lib/python3.10/site-packages (from contextily) (2.31.0)
# Requirement already satisfied: joblib in /opt/mamba/lib/python3.10/site-packages (from contextily) (1.3.2)
# Requirement already satisfied: xyzservices in /opt/mamba/lib/python3.10/site-packages (from contextily) (2023.10.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/mamba/lib/python3.10/site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /opt/mamba/lib/python3.10/site-packages (from mercantile->contextily) (8.1.7)
# Requirement already satisfied: affine in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (23.1.0)
# Requirement already satisfied: certifi in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (2023.7.22)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /opt/mamba/lib/python3.10/site-packages (from rasterio->contextily) (68.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/mamba/lib/python3.10/site-packages (from requests->contextily) (1.26.18)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Requirement already satisfied: geopandas in /opt/mamba/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas>=1.0.0 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: shapely>=1.7 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: fiona>=1.8 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.10/site-packages (from geopandas) (23.1)
# Requirement already satisfied: attrs>=19.2.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (2023.7.22)
# Requirement already satisfied: click~=8.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (4.0.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->geopandas) (1.16.0)
# Requirement already satisfied: topojson in /opt/mamba/lib/python3.10/site-packages (1.7)
# Requirement already satisfied: numpy in /opt/mamba/lib/python3.10/site-packages (from topojson) (1.26.0)
# Requirement already satisfied: shapely in /opt/mamba/lib/python3.10/site-packages (from topojson) (2.0.2)
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.10/site-packages (from topojson) (23.1)

# %%
"""Librairies nécessaires"""
import pandas as pd
import numpy as np
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt

# %%
"""Commandes (optionnelles) si le fichier n'est pas trouvé par la suite:

import os
os.getcwd() #trouver le directory actuel 
os.chdir('/home/onyxia/work/Projet-Stat-App-2A') #changer le directory

remarques sur github, commandes du terminal :
- ls : lister 
- cd : change directory 
    cd projet-stat-app-2A

"""

# %%
"""Installation de cartiflette dans le terminal"""

# !pip install requests py7zr geopandas openpyxl tqdm s3fs PyYAML xlrd
# !pip install git+https://github.com/inseefrlab/cartiflette@80b8a5a28371feb6df31d55bcc2617948a5f9b1a
# Out:
# Requirement already satisfied: requests in /opt/mamba/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: py7zr in /opt/mamba/lib/python3.10/site-packages (0.20.8)
# Requirement already satisfied: geopandas in /opt/mamba/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: openpyxl in /opt/mamba/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: tqdm in /opt/mamba/lib/python3.10/site-packages (4.66.1)
# Requirement already satisfied: s3fs in /opt/mamba/lib/python3.10/site-packages (2023.10.0)
# Requirement already satisfied: PyYAML in /opt/mamba/lib/python3.10/site-packages (6.0.1)
# Requirement already satisfied: xlrd in /opt/mamba/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/mamba/lib/python3.10/site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/mamba/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/mamba/lib/python3.10/site-packages (from requests) (2023.7.22)
# Requirement already satisfied: texttable in /opt/mamba/lib/python3.10/site-packages (from py7zr) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr) (3.19.0)
# Requirement already satisfied: pyzstd>=0.15.9 in /opt/mamba/lib/python3.10/site-packages (from py7zr) (0.15.9)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /opt/mamba/lib/python3.10/site-packages (from py7zr) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr) (1.1.0)
# Requirement already satisfied: psutil in /opt/mamba/lib/python3.10/site-packages (from py7zr) (5.9.5)
# Requirement already satisfied: pandas>=1.0.0 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: shapely>=1.7 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: fiona>=1.8 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (1.9.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /opt/mamba/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.10/site-packages (from geopandas) (23.1)
# Requirement already satisfied: et-xmlfile in /opt/mamba/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: aiobotocore~=2.7.0 in /opt/mamba/lib/python3.10/site-packages (from s3fs) (2.7.0)
# Requirement already satisfied: fsspec==2023.10.0 in /opt/mamba/lib/python3.10/site-packages (from s3fs) (2023.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/mamba/lib/python3.10/site-packages (from s3fs) (3.8.6)
# Requirement already satisfied: botocore<1.31.65,>=1.31.16 in /opt/mamba/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs) (1.31.64)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/mamba/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/mamba/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs) (0.11.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: click~=8.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas) (4.0.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas) (2023.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/mamba/lib/python3.10/site-packages (from botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs) (1.0.1)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->geopandas) (1.16.0)
# Collecting git+https://github.com/inseefrlab/cartiflette@80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Cloning https://github.com/inseefrlab/cartiflette (to revision 80b8a5a28371feb6df31d55bcc2617948a5f9b1a) to /tmp/pip-req-build-vab3p5_b
#   Running command git clone --filter=blob:none --quiet https://github.com/inseefrlab/cartiflette /tmp/pip-req-build-vab3p5_b
#   Running command git rev-parse -q --verify 'sha^80b8a5a28371feb6df31d55bcc2617948a5f9b1a'
#   Running command git fetch -q https://github.com/inseefrlab/cartiflette 80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Running command git checkout -q 80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Resolved https://github.com/inseefrlab/cartiflette to commit 80b8a5a28371feb6df31d55bcc2617948a5f9b1a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (6.0.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (1.4.4)
# Requirement already satisfied: geopandas<0.13.0,>=0.12.2 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (0.12.2)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (3.8.1)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.1 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (3.1.2)
# Requirement already satisfied: owslib<0.29.0,>=0.28.1 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (0.28.1)
# Requirement already satisfied: py7zr<0.21.0,>=0.20.4 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (0.20.8)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (2.31.0)
# Requirement already satisfied: s3fs<2024.0.0,>=2023.3.0 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (2023.10.0)
# Requirement already satisfied: topojson<2.0,>=1.5 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (1.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (4.66.1)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /opt/mamba/lib/python3.10/site-packages (from cartiflette==0.0.1) (2.0.1)
# Requirement already satisfied: pandas>=1.0.0 in /opt/mamba/lib/python3.10/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (2.1.3)
# Requirement already satisfied: shapely>=1.7 in /opt/mamba/lib/python3.10/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (2.0.2)
# Requirement already satisfied: fiona>=1.8 in /opt/mamba/lib/python3.10/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (1.9.3)
# Requirement already satisfied: pyproj>=2.6.1.post1 in /opt/mamba/lib/python3.10/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (3.6.1)
# Requirement already satisfied: packaging in /opt/mamba/lib/python3.10/site-packages (from geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (1.26.0)
# Requirement already satisfied: pillow>=8 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.10/site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (2.8.2)
# Requirement already satisfied: et-xmlfile in /opt/mamba/lib/python3.10/site-packages (from openpyxl<4.0.0,>=3.1.1->cartiflette==0.0.1) (1.1.0)
# Requirement already satisfied: lxml in /opt/mamba/lib/python3.10/site-packages (from owslib<0.29.0,>=0.28.1->cartiflette==0.0.1) (4.9.3)
# Requirement already satisfied: pytz in /opt/mamba/lib/python3.10/site-packages (from owslib<0.29.0,>=0.28.1->cartiflette==0.0.1) (2023.3.post1)
# Requirement already satisfied: texttable in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (3.19.0)
# Requirement already satisfied: pyzstd>=0.15.9 in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (0.15.9)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (1.1.0)
# Requirement already satisfied: psutil in /opt/mamba/lib/python3.10/site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette==0.0.1) (5.9.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/mamba/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/mamba/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/mamba/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/mamba/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.2->cartiflette==0.0.1) (2023.7.22)
# Requirement already satisfied: aiobotocore~=2.7.0 in /opt/mamba/lib/python3.10/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (2.7.0)
# Requirement already satisfied: fsspec==2023.10.0 in /opt/mamba/lib/python3.10/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (2023.10.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/mamba/lib/python3.10/site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (3.8.6)
# Requirement already satisfied: botocore<1.31.65,>=1.31.16 in /opt/mamba/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.31.64)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/mamba/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/mamba/lib/python3.10/site-packages (from aiobotocore~=2.7.0->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (0.11.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/mamba/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.3.1)
# Requirement already satisfied: click~=8.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (0.7.2)
# Requirement already satisfied: munch>=2.3.2 in /opt/mamba/lib/python3.10/site-packages (from fiona>=1.8->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (4.0.0)
# Requirement already satisfied: tzdata>=2022.1 in /opt/mamba/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas<0.13.0,>=0.12.2->cartiflette==0.0.1) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.1->cartiflette==0.0.1) (1.16.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/mamba/lib/python3.10/site-packages (from botocore<1.31.65,>=1.31.16->aiobotocore~=2.7.0->s3fs<2024.0.0,>=2023.3.0->cartiflette==0.0.1) (1.0.1)

# %%
"""Installation de cartiflette"""
from cartiflette.s3 import download_vectorfile_url_all

# %%
"""Données administratives de paris intra muros"""
paris_intra_muros = download_vectorfile_url_all(
    crs = 4326,
    values = ["75"],
    borders="COMMUNE_ARRONDISSEMENT",
    vectorfile_format="topojson",
    filter_by="DEPARTEMENT",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022)
# Out:
# https://minio.lab.sspcloud.fr/projet-cartiflette/diffusion/shapefiles-test1/year=2022/administrative_level=COMMUNE_ARRONDISSEMENT/crs=4326/DEPARTEMENT=75/vectorfile_format=topojson/provider=IGN/source=EXPRESS-COG-CARTO-TERRITOIRE/raw.topojson
# Downloading: : 40.1kiB [00:00, 41.6MiB/s]

# %%
def carte_prix_moyen_arrodissement(emplacement, année):
    #emplacement : emplacement du fichier (string)
    #année : année considérée (string)
    
    #lecture du fichier
    df = pd.read_csv(emplacement)

    #conversion du fichier en geopanda
    df_geo = gpd.GeoDataFrame(
        df, geometry=gpd.points_from_xy(df.longitude, df.latitude), crs="WGS84"
        )

    #on ajoute à chaque appartement les données administratives de son arrondissement
    df_geo = gpd.sjoin(df_geo, paris_intra_muros, predicate = 'within')

    #regroupement selon les arrondissements et prix moyen au m2
    df_geo_group = (df_geo
      .groupby("INSEE_COG")
      .agg({"prix_au_m2_réel": "mean"})
      .reset_index())

    #on ajoute aux données administratives les prix moyens
    paris_intra_muros_count = paris_intra_muros.merge(
        df_geo_group
    ).to_crs(2154)

    #affichage de la carte
    paris_intra_muros_count.plot(
    column = "prix_au_m2_réel", cmap="coolwarm", legend=True
    )

    plt.title(f'Prix moyen du m^2 par arrondissement en {année}') 
    plt.xticks([], [])
    plt.yticks([], [])
    plt.savefig(f"Visualisation/Prix moyen par arrondissement en {année}.png", dpi=300)

# %%
"""Test de la fonction"""

emplacement = "Données_clean/DVF_75_2020_clean.csv"
année = '2020'

carte_prix_moyen_arrodissement(emplacement, année)
# Out:
# /opt/mamba/lib/python3.10/site-packages/geopandas/plotting.py:730: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(values.dtype):
