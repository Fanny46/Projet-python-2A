# %%
"""Librairies nécessaires"""

import pandas as pd
from pandas import json_normalize
import geopandas as gpd

import numpy as np

import matplotlib.pyplot as plt

import json

import geopy.distance
from geopy.distance import geodesic as GD

from shapely.geometry import Point, Polygon
from shapely.ops import nearest_points

from tqdm import tqdm

# %%
"""Changement de directory pour lire les fichiers"""
import os
os.getcwd() #trouver le directory actuel 
os.chdir('/home/onyxia/work/Projet-Stat-App-2A')

# %%
"""Lecture du fichier des logements sociaux"""
emplacement_log_sociaux = '3.0) Enrichissement données/Données/Logements_sociaux_paris.geojson'
df_log_sociaux = gpd.read_file(emplacement_log_sociaux, low_memory=False, index_col=0)

# %%
"""On ne conserve que les logement sociaux de plus de 300 appartements"""
df_log_sociaux = df_log_sociaux.loc[df_log_sociaux['nb_logmt_total']>300]

# %%
"""Chargement des données administratives de Paris intra muros"""

paris_arrondissement = gpd.read_file('2) Visualisation/Données_carto/paris_arrondissements.geojson')

# %%
"""Visualisation des logements sociaux parisiens"""

fig, ax = plt.subplots(figsize=(8, 7))

paris_arrondissement.boundary.plot(ax=ax, edgecolor = "red", linewidth = 0.7) #on ajout les arrondissements parisiens en rouge

df_log_sociaux.plot(ax=ax, color='green', alpha=0.7, edgecolor='black', linewidth=1) #on ajoute les lycées

#rien sur les axes
plt.xticks([], [])
plt.yticks([], [])

#titre
plt.title('Carte des logements sociaux (de plus de 300 appartements)')
plt.savefig('3.0) Enrichissement données/Sorties_cartes/carte_logements_sociaux_paris.png')
plt.show()

# %%
"""Fonction qui ajoute aux appartements le logement social le plus proche"""

def ajouter_log_sociaux(dvf, df_log_sociaux):
    
    #dvf : geodataframe contenant la localisation de l'appartement dans une colonne 'geometry' au format WSG84
    #df_sites_tour : geodataframe contenant la localisation des logements sociaux dans une colonne 'geometry' au format WSG84

    #la fonction ajoute une colonne à dvf : dist_min_log_social
    
    # Définir la projection équidistante (EPSG:3395)
    dvf = dvf.to_crs(epsg=3395)
    df_log_sociaux = df_log_sociaux.to_crs(epsg=3395)
        
    # Fonction pour trouver le logement social la plus proche
    def find_nearest_log_social(row):
        nearest_log_social = df_log_sociaux.geometry == nearest_points(row['geometry'], df_log_sociaux.unary_union)[1]
        return pd.Series({
            'dist_min_log_social': row['geometry'].distance(df_log_sociaux.loc[nearest_log_social, 'geometry'].values[0]) / 1000,  # Conversion en kilomètres
        })
    
    # Appliquer la fonction pour chaque appartement
    tqdm.pandas()  # Barre de progression pour les itérations
    dvf[['dist_min_log_social']] = dvf.progress_apply(find_nearest_log_social, axis=1)

    # Reconvertir en WGS 84 (EPSG:4326)
    dvf_result = dvf.to_crs(epsg=4326)
    
    return dvf_result

# %%
"""Chargement fichier dvf"""

#chemin du fichier dvf
path_folder = '1.2) Données_concat/'
name_file = 'dvf_concat_2021_to_2023.geojson'
path_file = path_folder + name_file

#lecture du fichier dvf
dvf = gpd.read_file(path_file)

#chemin export
outer_path = '3.1) Données_enrichies/'

# %%
"""Fonction qui applique ajouter_log_sociaux et exporte le fichier"""

def ajouter_log_sociaux_export(dvf, outer_path):

    #on applique la fonction ajouter_log_sociaux
    dvf_enrichi = ajouter_log_sociaux(dvf, df_log_sociaux)

    #nom du fichier de sortie
    name_file_without_extension = os.path.splitext(name_file)[0]
    outer_name = f'{name_file_without_extension}_avec_log_sociaux.geojson'

    #on exporte
    dvf_enrichi.to_file(outer_path+outer_name, driver='GeoJSON')

    return dvf_enrichi

# %%
"""Ajouter les logements sociaux au fichier dvf"""

dvf_enrichi = ajouter_log_sociaux_export(dvf, outer_path)
# Out:
# 100%|██████████| 59417/59417 [02:14<00:00, 442.09it/s]
